# %% [markdown]
# <a href="https://colab.research.google.com/github/Pubudu-98/Colab/blob/main/Python_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basics

# %%
a = 10
b = 20

tmp = a
a = b
b = a

print(a)
print(b)
# Out:
# 20
# 20

# %%
type(a)
type(b)
# Out:
# int

# %% [markdown]
# # ATM Operation in Python

# %% [markdown]
# ## ATM Operation with Streamlit GUI
#
# To run this Streamlit application, you will need to install strealit (Python framework) first. After installing, save the code into a Python file and run `streamlit run file_name.py` in the terminal.

# %%
pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 73.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 100.1 MB/s eta 0:00:00
# ...

# %%
import streamlit as st
