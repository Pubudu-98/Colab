# %% [markdown]
# <a href="https://colab.research.google.com/github/Pubudu-98/Colab/blob/main/Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Testing Colab CPU & GPU

# %%
import torch
import time

def compute(device):

    x = torch.rand(10000, 10000, device=device)

    start = time.time()

    y = x @ x

    torch.cuda.synchronize() if device == 'cuda' else None
    end = time.time()
    print(end-start)

# %%
compute('cpu') # CPU performence
# Out:
# 19.78734254837036

# %%
compute('cuda') # GPU performence
# Out:
# 0.549095869064331
