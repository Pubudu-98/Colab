# %% [markdown]
# <a href="https://colab.research.google.com/github/Pubudu-98/Colab/blob/main/house_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = 10
b = 20

tmp = a
a = b
b = a

print(a)
print(b)
# Out:
# 20
# 20

# %%
my_pass = 0
my_pass = 0 + 7

if my_pass > 5:
  print('I have passed!')
else:
  print('I have not passed!')
# Out:
# I have passed!
